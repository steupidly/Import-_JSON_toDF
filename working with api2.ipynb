# %%
import pandas as pd
import requests
pd.options.display.max_columns = 30

# %%
api_key = "api_key=28681f143b15a37d1f333878f44199e0"

# %%
discover_api = "https://api.themoviedb.org/3/discover/movie?"

# %%
query = "&primary_release_date.gte=2022-01-01&primary_release_date.lte=2022-02-29"

# %%
url = discover_api+api_key+query

# %%
data = requests.get(url).json()

# %%
df = pd.DataFrame(data)
df
# Out:
#     page                                            results  total_pages  \
# 0      1  {'adult': False, 'backdrop_path': '/zlLQXKsSa2...          191
# 1      1  {'adult': False, 'backdrop_path': '/jazlkwXfw4...          191
# 2      1  {'adult': False, 'backdrop_path': '/nYla7faWqM...          191
# 3      1  {'adult': False, 'backdrop_path': '/as4jvr6PF7...          191
# 4      1  {'adult': False, 'backdrop_path': '/xHRabofjmM...          191
# 5      1  {'adult': False, 'backdrop_path': '/m3Ys7UDzUz...          191
# 6      1  {'adult': False, 'backdrop_path': '/noCgyITVoR...          191
# 7      1  {'adult': False, 'backdrop_path': '/aEGiJJP91H...          191
# 8      1  {'adult': False, 'backdrop_path': '/8QpzqK3nPG...          191
# 9      1  {'adult': False, 'backdrop_path': '/An1nKjXahr...          191
# 10     1  {'adult': False, 'backdrop_path': '/tzNx4y7kYf...          191
# 11     1  {'adult': False, 'backdrop_path': '/4dNv1W1KMS...          191
# 12     1  {'adult': False, 'backdrop_path': '/eVSa4TpyXb...          191
# 13     1  {'adult': False, 'backdrop_path': '/eG0oOQVsni...          191
# 14     1  {'adult': False, 'backdrop_path': '/obTdaJ22RN...          191
# 15     1  {'adult': False, 'backdrop_path': '/2il2HT8v6N...          191
# 16     1  {'adult': False, 'backdrop_path': '/siEKPoFqIc...          191
# 17     1  {'adult': False, 'backdrop_path': '/mTupUmnuww...          191
# 18     1  {'adult': False, 'backdrop_path': '/iDeWAGnmlo...          191
# 19     1  {'adult': False, 'backdrop_path': '/aTSA5zMWlV...          191
#
#     total_results
# 0            3806
# 1            3806
# 2            3806
# 3            3806
# 4            3806
# 5            3806
# 6            3806
# 7            3806
# 8            3806
# 9            3806
# 10           3806
# 11           3806
# 12           3806
# 13           3806
# 14           3806
# 15           3806
# 16           3806
# 17           3806
# 18           3806
# 19           3806

# %%
pd.DataFrame(data['results'])
# Out:
#     adult                     backdrop_path                genre_ids      id  \
# 0   False  /zlLQXKsSa2CEkz3UBFWPUPX90PN.jpg                     [53]  968857
# 1   False  /jazlkwXfw4KdF6fVTRsolOvRCmu.jpg   [53, 12, 9648, 28, 80]  924482
# 2   False  /nYla7faWqM3nLCY9arQH1DwXC84.jpg          [16, 12, 10751]  576925
# 3   False  /as4jvr6PF7Wfs0RyUl5bOJcB3yt.jpg                 [18, 35]  626735
# 4   False  /xHRabofjmMGoIV3mb6xgy4nwOcS.jpg                     [27]  801071
# 5   False  /m3Ys7UDzUzOyoPYKzp4GhKKokUr.jpg  [16, 10751, 14, 35, 12]  585083
# 6   False  /noCgyITVoRxC3huC9zSOQq23sVr.jpg             [80, 53, 18]  821420
# 7   False  /aEGiJJP91HsKVTEPy1HhmN0wRLm.jpg                 [28, 12]  335787
# 8   False  /8QpzqK3nPGxpqpKqhe6QasTGBWQ.jpg            [878, 12, 28]  406759
# 9   False  /An1nKjXahrChfEbZ3MAE8fsiut1.jpg                     [27]  661791
# 10  False  /tzNx4y7kYf1Xw3F3T6QxrE7PPwb.jpg   [53, 18, 80, 9648, 27]  825808
# 11  False  /4dNv1W1KMSLdYGz0tCEaynF0E4Q.jpg             [28, 53, 80]  854467
# 12  False  /eVSa4TpyXbOdk9fXSD6OcORJGtv.jpg                 [53, 27]  803114
# 13  False  /eG0oOQVsniPAuecPzDD1B1gnYWy.jpg      [16, 35, 12, 10751]  774825
# 14  False  /obTdaJ22RNFi3fmzUVT5eWOFsOe.jpg                 [53, 80]  728366
# 15  False  /2il2HT8v6NAN7oinOCuHKpEhgnB.jpg           [27, 53, 9648]  833425
# 16  False  /siEKPoFqIctmu1c29Ggj4ZWQFv6.jpg                 [35, 18]  757999
# 17  False  /mTupUmnuwwAyA0CNqpwaZn5mqjk.jpg  [28, 27, 53, 10752, 14]  697799
# 18  False  /iDeWAGnmloZ5Oz3bocDp4rSbUXd.jpg                 [28, 53]  823625
# 19  False  /aTSA5zMWlVFTYBIZxTCMbLkfOtb.jpg                 [27, 53]  632727
#
#    original_language                       original_title  \
# 0                 en                       Looks Can Kill
# 1                 en                            The Ledge
# 2                 ru            Buka. My favorite monster
# 3                 en                                  Dog
# 4                 en       The Jack in the Box: Awakening
# 5                 en    Hotel Transylvania: Transformania
# 6                 en                   Catch the Fair One
# 7                 en                            Uncharted
# 8                 en                             Moonfall
# 9                 es                            La abuela
# 10                en                           See for Me
# 11                en                            Indemnity
# 12                en                           The Requin
# 13                en  The Ice Age Adventures of Buck Wild
# 14                en                              Borrego
# 15                en                              No Exit
# 16                fr                              Presque
# 17                en                              WarHunt
# 18                en                           Blacklight
# 19                en              Texas Chainsaw Massacre
#
#                                              overview  popularity  \
# 0   A group of models is killed off, one by one, a...    1259.824
# 1   A rock climbing adventure between two friends ...    1157.751
# 2   A scandal in the royal family: the wayward pri...     975.693
# 3   An army ranger and his dog embark on a road tr...     666.748
# 4   When a vintage Jack-in-the-box is opened by a ...     594.066
# 5   When Van Helsing's mysterious invention, the "...     598.611
# 6   A Native American boxer embarks on the fight o...     616.548
# 7   A young street-smart, Nathan Drake and his wis...     575.023
# 8   A mysterious force knocks the moon from its or...     550.910
# 9   A Paris model must return to Madrid where her ...     466.462
# 10  When blind former skier Sophie cat-sits in a s...     398.853
# 11  An ex-fireman with PTSD goes on the run when a...     427.489
# 12  A couple on a romantic getaway find themselves...     419.817
# 13  The fearless one-eyed weasel Buck teams up wit...     389.504
# 14  A young botanist relocates to a small desert t...     408.359
# 15  Stranded at a rest stop in the mountains durin...     384.745
# 16  Two men, why vastly different life stories and...     323.306
# 17  1945. A U.S. military cargo plane loses contro...     347.444
# 18  Travis Block is a shadowy Government agent who...     341.490
# 19  After nearly 50 years of hiding, Leatherface r...     301.990
#
#                          poster_path release_date  \
# 0   /1uy2PNFwtkqH3mhGd6irk5aeIrF.jpg   2022-02-01
# 1   /dHKfsdNcEPw7YIWFPIhqiuWrSAb.jpg   2022-02-18
# 2   /xIbEHAqwK5N7PJJYmbwmxuvC7fL.jpg   2022-01-27
# 3   /zHQy4h36WwuCetKS7C3wcT1hkgA.jpg   2022-02-17
# 4   /3Ib8vlWTrAKRrTWUrTrZPOMW4jp.jpg   2022-02-24
# 5   /teCy1egGQa0y8ULJvlrDHQKnxBL.jpg   2022-02-25
# 6   /35QvPu5nOGlzDIGOdvtRNNkfjLZ.jpg   2022-02-11
# 7   /rJHC1RUORuUhtfNb4Npclx0xnOf.jpg   2022-02-10
# 8   /odVv1sqVs0KxBXiA8bhIBlPgalx.jpg   2022-02-03
# 9   /eIUixNvox4U4foL5Z9KbN9HXYSM.jpg   2022-01-28
# 10  /qk1ZERG6yhwAJqTobmDgw8jRL2C.jpg   2022-01-07
# 11  /tVbO8EAbegVtVkrl8wNhzoxS84N.jpg   2022-02-11
# 12  /i0z8g2VRZP3dhVvvSMilbOZMKqR.jpg   2022-01-28
# 13  /zzXFM4FKDG7l1ufrAkwQYv2xvnh.jpg   2022-01-28
# 14  /kPzQtr5LTheO0mBodIeAXHgthYX.jpg   2022-01-14
# 15  /5cnLoWq9o5tuLe1Zq4BTX4LwZ2B.jpg   2022-02-25
# 16  /7BRRlZ5XWz9EC4pjPy66zKgQwCk.jpg   2022-01-19
# 17  /9HFFwZOTBB7IPFmn9E0MXdWave3.jpg   2022-01-21
# 18  /bv9dy8mnwftdY2j6gG39gCfSFpV.jpg   2022-02-10
# 19  /e8vYPpkUJpf5Ils99kxF0Ev73ay.jpg   2022-02-18
#
#                                   title  video  vote_average  vote_count
# 0                        Looks Can Kill  False           6.1           6
# 1                             The Ledge  False           6.3         102
# 2                      My Sweet Monster  False           6.0          10
# 3                                   Dog  False           7.4         878
# 4        The Jack in the Box: Awakening  False           6.4         136
# 5     Hotel Transylvania: Transformania  False           7.1        1206
# 6                    Catch the Fair One  False           6.4          27
# 7                             Uncharted  False           7.1        3474
# 8                              Moonfall  False           6.4        1833
# 9                       The Grandmother  False           5.8         260
# 10                           See for Me  False           6.1         106
# 11                            Indemnity  False           7.1          66
# 12                           The Requin  False           4.6         176
# 13  The Ice Age Adventures of Buck Wild  False           6.8        1354
# 14                              Borrego  False           6.0          45
# 15                              No Exit  False           7.0         710
# 16                      Beautiful Minds  False           7.6          64
# 17                              WarHunt  False           5.1          56
# 18                           Blacklight  False           6.3         654
# 19              Texas Chainsaw Massacre  False           5.3         937
